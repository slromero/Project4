# %%
import pandas as pd
import numpy as np

# %%
# Load the CSV file
df = pd.read_csv("Resources/bridge_testing_dataset.csv",low_memory=False)
df2 = df.dropna()

# %%
# Selecting NY and CA,N DAKOTA, NEW MEXICO, FLORIDA  states
df2 = df2.loc[(df2['STATE_CODE_001'] == 36) | (df2['STATE_CODE_001'] == 6) |(df2['STATE_CODE_001'] == 38)|(df2['STATE_CODE_001'] == 35)|(df2['STATE_CODE_001'] == 12)|(df2['STATE_CODE_001'] == 8) |(df2['STATE_CODE_001'] == 29),:]
df2.head()
# Out:
#        OBJECTID  STATE_CODE_001  ROUTE_PREFIX_005B  SERVICE_LEVEL_005C  \
# 39357     39358               6                  1                   1
# 39358     39359               6                  7                   0
# 39359     39360               6                  6                   6
# 39360     39361               6                  8                   0
# 39361     39362               6                  6                   6
#
#       FEATURES_DESC_006A  MIN_VERT_CLR_010  BASE_HWY_NETWORK_012  TOLL_020  \
# 39357               road             99.99                   1.0         3
# 39358              river             99.99                   0.0         3
# 39359               road             99.99                   0.0         3
# 39360               road             99.99                   0.0         3
# 39361              canal             99.99                   0.0         3
#
#        FUNCTIONAL_CLASS_026  TRAFFIC_LANES_ON_028A  TRAFFIC_LANES_UND_028B  \
# 39357                     1                      4                       0
# 39358                     9                      1                       0
# 39359                     9                      2                       0
# 39360                    19                      2                       2
# 39361                     9                      2                       0
#
#        ADT_029 DESIGN_LOAD_031  APPR_WIDTH_MT_032  DEGREES_SKEW_034  \
# 39357    19500               4               21.8                 0
# 39358       75               2                3.7                 0
# 39359      200               4               10.0                 0
# 39360      100               5                7.2                 0
# 39361      200               4               14.6                 0
#
#        STRUCTURE_FLARED_035 RAILINGS_036A TRANSITIONS_036B NAVIGATION_038  \
# 39357                     0             1                1              0
# 39358                     0             0                0              0
# 39359                     0             0                0              N
# 39360                     0             1                N              N
# 39361                     0             1                0              N
#
#        NAV_VERT_CLR_MT_039  NAV_HORR_CLR_MT_040  STRUCTURE_TYPE_043B  \
# 39357                  0.0                  0.0                    9
# 39358                  0.0                  0.0                   10
# 39359                  0.0                  0.0                    4
# 39360                  0.0                  0.0                    2
# 39361                  0.0                  0.0                    5
#
#        MAIN_UNIT_SPANS_045  APPR_SPANS_046  HORR_CLR_MT_047  \
# 39357                    8               7              8.6
# 39358                    1               3              3.6
# 39359                    1               0             13.5
# 39360                    5               0              7.2
# 39361                    4               0             14.6
#
#        MAX_SPAN_LEN_MT_048  STRUCTURE_LEN_MT_049  ROADWAY_WIDTH_MT_051  \
# 39357                192.0                1093.6                  17.2
# 39358                 39.6                  67.7                   3.6
# 39359                 10.4                  10.4                  13.5
# 39360                 18.9                  60.8                   7.2
# 39361                  6.9                  27.4                  14.6
#
#        DECK_WIDTH_MT_052  VERT_CLR_OVER_MT_053 VERT_CLR_UND_REF_054A  \
# 39357               18.9                 99.99                     R
# 39358                4.0                 99.99                     N
# 39359               17.2                 99.99                     N
# 39360               10.7                 99.99                     H
# 39361               15.9                 99.99                     N
#
#        VERT_CLR_UND_054B DECK_COND_058 SUPERSTRUCTURE_COND_059  \
# 39357               0.49             5                       7
# 39358               0.00             5                       6
# 39359               0.00             5                       4
# 39360               6.40             6                       7
# 39361               0.00             7                       6
#
#       SUBSTRUCTURE_COND_060 CHANNEL_COND_061 CULVERT_COND_062  \
# 39357                     7                9                N
# 39358                     3                5                N
# 39359                     5                6                N
# 39360                     7                N                N
# 39361                     5                7                N
#
#        OPERATING_RATING_064 STRUCTURAL_EVAL_067 DECK_GEOMETRY_EVAL_068  \
# 39357                  58.1                   7                      4
# 39358                  27.0                   3                      3
# 39359                  44.7                   4                      9
# 39360                  81.3                   7                      5
# 39361                  41.2                   5                      9
#
#       UNDCLRENCE_EVAL_069 WATERWAY_EVAL_071  APPR_ROAD_EVAL_072  \
# 39357                   3                 9                 6.0
# 39358                   N                 6                 3.0
# 39359                   N                 8                 8.0
# 39360                   3                 N                 6.0
# 39361                   N                 5                 8.0
#
#        IMP_LEN_MT_076  DATE_OF_INSPECT_090  INSPECT_FREQ_MONTHS_091  \
# 39357             0.0                  522                       24
# 39358             0.0                  518                       24
# 39359            10.4                  721                       24
# 39360            60.8                  721                       24
# 39361            27.4                  721                       24
#
#       FRACTURE_092A UNDWATER_LOOK_SEE_092B SPEC_INSPECT_092C  \
# 39357           Y24                    Y60                 N
# 39358           Y24                    Y60             Other
# 39359             N                    Y60                 N
# 39360             N                      N                 N
# 39361             N                      N                 N
#
#        BRIDGE_IMP_COST_094  ROADWAY_IMP_COST_095  TOTAL_IMP_COST_096  \
# 39357                  0.0                   0.0                 0.0
# 39358                  0.0                   0.0                 0.0
# 39359                208.0                 108.0               316.0
# 39360                 18.0                   1.0                19.0
# 39361                 70.0                  20.0               900.0
#
#        STRAHNET_HIGHWAY_100 PARALLEL_STRUCTURE_101  HIGHWAY_SYSTEM_104  \
# 39357                     1                      N                   1
# 39358                     0                      N                   0
# 39359                     0                      N                   0
# 39360                     0                      N                   0
# 39361                     0                      N                   0
#
#       DECK_STRUCTURE_TYPE_107 SURFACE_TYPE_108A MEMBRANE_TYPE_108B  \
# 39357                       1                 1                  0
# 39358                       8                 0                  0
# 39359                       2                 6                  8
# 39360                       1                 1                  N
# 39361                       2                 6                  8
#
#       DECK_PROTECTION_108C  PERCENT_ADT_TRUCK_109  NATIONAL_NETWORK_110  \
# 39357                    1                   29.0                     1
# 39358                    0                    0.0                     0
# 39359                    8                    2.0                     0
# 39360                    8                   20.0                     0
# 39361                    8                    2.0                     0
#
#        PIER_PROTECTION_111 BRIDGE_LEN_IND_112 SCOUR_CRITICAL_113  \
# 39357                  0.0                  Y                  8
# 39358                  0.0                  Y                  2
# 39359                  1.0                  Y                  5
# 39360                  0.0                  Y                  N
# 39361                  0.0                  Y                  5
#
#        FUTURE_ADT_114  MIN_NAV_CLR_MT_116 FED_AGENCY BRIDGE_CONDITION  \
# 39357           37258                 0.0          Y                F
# 39358             156                 0.0          Y                P
# 39359             250                 0.0          Y                P
# 39360             100                 0.0          Y                F
# 39361             250                 0.0          Y                F
#
#        LOWEST_RATING  DECK_AREA  DATE  bridge_age  future_adt_estimation
# 39357              5   20669.04   723          16                   25.0
# 39358              3     270.80  1202          89                   16.0
# 39359              4     178.88   723          75                   19.0
# 39360              6     650.56   723          39                   22.0
# 39361              5     435.66   723          64                   18.0

# %% [markdown]
# ### Balancing BRIDGE_CONDITION data (not necessary)

# %%
# # class count
# class_count_G, class_count_F, class_count_P = df2['BRIDGE_CONDITION'].value_counts()

# # Separate class
# class_G = df2[df2['BRIDGE_CONDITION'] == 'G']
# class_F = df2[df2['BRIDGE_CONDITION'] == 'F']
# class_P = df2[df2['BRIDGE_CONDITION'] == 'P']  
# print('class G:', class_G.shape)
# print('class F:', class_F.shape)
# print('class P:', class_P.shape)

# # Random Under-Sampling
# class_G_under = class_G.sample(class_count_P)
# class_F_under = class_F.sample(class_count_P)

# df2 = pd.concat([class_G_under,class_F_under, class_P], axis=0)

# print("total class of G,F and P:",df2['BRIDGE_CONDITION'].value_counts())# plot the count after under-sampeling
# df2['BRIDGE_CONDITION'].value_counts().plot(kind='bar', rot =0, title='count (target)')

# %%
# Select columns of object data type
object_columns = df2.select_dtypes(include=['object']).columns

# Drop object data type columns
df2_filtered = df2.drop(object_columns, axis=1)
df2_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 98159 entries, 39357 to 391633
# Data columns (total 46 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   OBJECTID                 98159 non-null  int64
#  1   STATE_CODE_001           98159 non-null  int64
#  2   ROUTE_PREFIX_005B        98159 non-null  int64
#  3   SERVICE_LEVEL_005C       98159 non-null  int64
#  4   MIN_VERT_CLR_010         98159 non-null  float64
#  5   BASE_HWY_NETWORK_012     98159 non-null  float64
#  6   TOLL_020                 98159 non-null  int64
#  7   FUNCTIONAL_CLASS_026     98159 non-null  int64
#  8   TRAFFIC_LANES_ON_028A    98159 non-null  int64
#  9   TRAFFIC_LANES_UND_028B   98159 non-null  int64
#  10  ADT_029                  98159 non-null  int64
#  11  APPR_WIDTH_MT_032        98159 non-null  float64
#  12  DEGREES_SKEW_034         98159 non-null  int64
#  13  STRUCTURE_FLARED_035     98159 non-null  int64
#  14  NAV_VERT_CLR_MT_039      98159 non-null  float64
#  15  NAV_HORR_CLR_MT_040      98159 non-null  float64
#  16  STRUCTURE_TYPE_043B      98159 non-null  int64
#  17  MAIN_UNIT_SPANS_045      98159 non-null  int64
#  18  APPR_SPANS_046           98159 non-null  int64
#  19  HORR_CLR_MT_047          98159 non-null  float64
#  20  MAX_SPAN_LEN_MT_048      98159 non-null  float64
#  21  STRUCTURE_LEN_MT_049     98159 non-null  float64
#  22  ROADWAY_WIDTH_MT_051     98159 non-null  float64
#  23  DECK_WIDTH_MT_052        98159 non-null  float64
#  24  VERT_CLR_OVER_MT_053     98159 non-null  float64
#  25  VERT_CLR_UND_054B        98159 non-null  float64
#  26  OPERATING_RATING_064     98159 non-null  float64
#  27  APPR_ROAD_EVAL_072       98159 non-null  float64
#  28  IMP_LEN_MT_076           98159 non-null  float64
#  29  DATE_OF_INSPECT_090      98159 non-null  int64
#  30  INSPECT_FREQ_MONTHS_091  98159 non-null  int64
#  31  BRIDGE_IMP_COST_094      98159 non-null  float64
#  32  ROADWAY_IMP_COST_095     98159 non-null  float64
#  33  TOTAL_IMP_COST_096       98159 non-null  float64
#  34  STRAHNET_HIGHWAY_100     98159 non-null  int64
#  35  HIGHWAY_SYSTEM_104       98159 non-null  int64
#  36  PERCENT_ADT_TRUCK_109    98159 non-null  float64
#  37  NATIONAL_NETWORK_110     98159 non-null  int64
#  38  PIER_PROTECTION_111      98159 non-null  float64
#  39  FUTURE_ADT_114           98159 non-null  int64
#  40  MIN_NAV_CLR_MT_116       98159 non-null  float64
#  41  LOWEST_RATING            98159 non-null  int64
#  42  DECK_AREA                98159 non-null  float64
#  43  DATE                     98159 non-null  int64
#  44  bridge_age               98159 non-null  int64
#  45  future_adt_estimation    98159 non-null  float64
# dtypes: float64(23), int64(23)
# memory usage: 35.2 MB

# %%
# Calculate correlation matrix
# calculate the correlation matrix of the features
corr_matrix = df2_filtered.corr()

# set the threshold for correlation value
corr_threshold = 0.77

# find the highly correlated features and drop them from the dataframe
high_corr_features = np.where(corr_matrix.abs() > corr_threshold)
high_corr_features = [(corr_matrix.columns[x], corr_matrix.columns[y]) for x, y in zip(*high_corr_features) if x != y and x < y]
df2_filtered.drop([col[1] for col in high_corr_features], axis=1, inplace=True)

# select the remaining features with low correlation
low_corr_features = df2_filtered.columns.tolist()

# print the low correlated features
print(low_corr_features)
# Out:
# ['OBJECTID', 'ROUTE_PREFIX_005B', 'SERVICE_LEVEL_005C', 'MIN_VERT_CLR_010', 'BASE_HWY_NETWORK_012', 'TOLL_020', 'FUNCTIONAL_CLASS_026', 'TRAFFIC_LANES_ON_028A', 'TRAFFIC_LANES_UND_028B', 'ADT_029', 'DEGREES_SKEW_034', 'STRUCTURE_FLARED_035', 'NAV_VERT_CLR_MT_039', 'NAV_HORR_CLR_MT_040', 'STRUCTURE_TYPE_043B', 'MAIN_UNIT_SPANS_045', 'APPR_SPANS_046', 'HORR_CLR_MT_047', 'MAX_SPAN_LEN_MT_048', 'STRUCTURE_LEN_MT_049', 'ROADWAY_WIDTH_MT_051', 'VERT_CLR_UND_054B', 'OPERATING_RATING_064', 'APPR_ROAD_EVAL_072', 'IMP_LEN_MT_076', 'DATE_OF_INSPECT_090', 'INSPECT_FREQ_MONTHS_091', 'BRIDGE_IMP_COST_094', 'STRAHNET_HIGHWAY_100', 'HIGHWAY_SYSTEM_104', 'PERCENT_ADT_TRUCK_109', 'NATIONAL_NETWORK_110', 'PIER_PROTECTION_111', 'MIN_NAV_CLR_MT_116', 'LOWEST_RATING', 'DATE', 'bridge_age', 'future_adt_estimation']

# %%
df3_filtered = df2_filtered[low_corr_features]

# %%
# Selecting the more important features
df3_filtered = df2[['ROUTE_PREFIX_005B', 'SERVICE_LEVEL_005C',
       'MIN_VERT_CLR_010', 'BASE_HWY_NETWORK_012', 'TOLL_020',
       'FUNCTIONAL_CLASS_026', 
       'TRAFFIC_LANES_ON_028A','TRAFFIC_LANES_UND_028B', 
       # 'ADT_029', 
       'APPR_WIDTH_MT_032',
       'DEGREES_SKEW_034', #'STRUCTURE_FLARED_035', 
       #'NAV_VERT_CLR_MT_039','NAV_HORR_CLR_MT_040', 
       'STRUCTURE_TYPE_043B', #'MAIN_UNIT_SPANS_045',
       'APPR_SPANS_046', 
       'HORR_CLR_MT_047', 
       'MAX_SPAN_LEN_MT_048','STRUCTURE_LEN_MT_049', 'ROADWAY_WIDTH_MT_051', 
       'VERT_CLR_OVER_MT_053','VERT_CLR_UND_054B', 'OPERATING_RATING_064', 
       'APPR_ROAD_EVAL_072',
       #'IMP_LEN_MT_076', 
       #'DATE_OF_INSPECT_090', 
       'INSPECT_FREQ_MONTHS_091',
       #'BRIDGE_IMP_COST_094', #'ROADWAY_IMP_COST_095', 
       #'STRAHNET_HIGHWAY_100',
       'HIGHWAY_SYSTEM_104', 'PERCENT_ADT_TRUCK_109', 'NATIONAL_NETWORK_110',
       'PIER_PROTECTION_111', #'MIN_NAV_CLR_MT_116', 
       #'LOWEST_RATING', 
       #'DATE',
       'bridge_age',
       'STRUCTURE_LEN_MT_049',
       # 'FEATURES_DESC_006A', 'DESIGN_LOAD_031',
       'STRUCTURAL_EVAL_067',
       ]]

# %%
# Set display option to show all columns
pd.set_option('display.max_columns', None)
df3_filtered
# Out:
#         ROUTE_PREFIX_005B  SERVICE_LEVEL_005C  MIN_VERT_CLR_010  \
# 39357                   1                   1             99.99
# 39358                   7                   0             99.99
# 39359                   6                   6             99.99
# 39360                   8                   0             99.99
# 39361                   6                   6             99.99
# ...                   ...                 ...               ...
# 391629                  3                   1             99.99
# 391630                  6                   0             99.99
# 391631                  6                   0             99.99
# 391632                  8                   8             99.99
# 391633                  5                   1             99.99
#
#         BASE_HWY_NETWORK_012  TOLL_020  FUNCTIONAL_CLASS_026  \
# 39357                    1.0         3                     1
# 39358                    0.0         3                     9
# 39359                    0.0         3                     9
# 39360                    0.0         3                    19
# 39361                    0.0         3                     9
# ...                      ...       ...                   ...
# 391629                   0.0         3                     2
# 391630                   0.0         3                    19
# 391631                   0.0         3                    19
# 391632                   0.0         3                     9
# 391633                   0.0         3                    17
#
#         TRAFFIC_LANES_ON_028A  TRAFFIC_LANES_UND_028B  APPR_WIDTH_MT_032  \
# 39357                       4                       0               21.8
# 39358                       1                       0                3.7
# 39359                       2                       0               10.0
# 39360                       2                       2                7.2
# 39361                       2                       0               14.6
# ...                       ...                     ...                ...
# 391629                      2                       0                7.9
# 391630                      2                       0               10.4
# 391631                      2                       0               10.4
# 391632                      2                       0                6.7
# 391633                      2                       0                8.5
#
#         DEGREES_SKEW_034  STRUCTURE_TYPE_043B  APPR_SPANS_046  \
# 39357                  0                    9               7
# 39358                  0                   10               3
# 39359                  0                    4               0
# 39360                  0                    2               0
# 39361                  0                    5               0
# ...                  ...                  ...             ...
# 391629                 0                    3               0
# 391630                 3                   19               0
# 391631                11                   19               0
# 391632                 0                    5               0
# 391633                 0                   19               0
#
#         HORR_CLR_MT_047  MAX_SPAN_LEN_MT_048  STRUCTURE_LEN_MT_049  \
# 39357               8.6                192.0                1093.6
# 39358               3.6                 39.6                  67.7
# 39359              13.5                 10.4                  10.4
# 39360               7.2                 18.9                  60.8
# 39361              14.6                  6.9                  27.4
# ...                 ...                  ...                   ...
# 391629              7.9                 13.3                 480.0
# 391630             10.4                  3.0                   6.3
# 391631             10.4                  3.1                   6.5
# 391632              6.0                 12.1                  12.1
# 391633              5.2                  3.7                   7.6
#
#         ROADWAY_WIDTH_MT_051  VERT_CLR_OVER_MT_053  VERT_CLR_UND_054B  \
# 39357                   17.2                 99.99               0.49
# 39358                    3.6                 99.99               0.00
# 39359                   13.5                 99.99               0.00
# 39360                    7.2                 99.99               6.40
# 39361                   14.6                 99.99               0.00
# ...                      ...                   ...                ...
# 391629                   7.9                 99.99               0.00
# 391630                   0.0                 99.99               0.00
# 391631                   0.0                 99.99               0.00
# 391632                   6.0                 99.99               0.00
# 391633                   0.0                 99.99               0.00
#
#         OPERATING_RATING_064  APPR_ROAD_EVAL_072  INSPECT_FREQ_MONTHS_091  \
# 39357                   58.1                 6.0                       24
# 39358                   27.0                 3.0                       24
# 39359                   44.7                 8.0                       24
# 39360                   81.3                 6.0                       24
# 39361                   41.2                 8.0                       24
# ...                      ...                 ...                      ...
# 391629                  29.8                 7.0                       24
# 391630                  65.3                 8.0                       24
# 391631                  99.9                 8.0                       24
# 391632                  38.6                 6.0                       24
# 391633                  68.0                 7.0                       24
#
#         HIGHWAY_SYSTEM_104  PERCENT_ADT_TRUCK_109  NATIONAL_NETWORK_110  \
# 39357                    1                   29.0                     1
# 39358                    0                    0.0                     0
# 39359                    0                    2.0                     0
# 39360                    0                   20.0                     0
# 39361                    0                    2.0                     0
# ...                    ...                    ...                   ...
# 391629                   1                   20.0                     0
# 391630                   0                    0.0                     0
# 391631                   0                    0.0                     0
# 391632                   0                    1.0                     0
# 391633                   0                    5.0                     0
#
#         PIER_PROTECTION_111  bridge_age  STRUCTURE_LEN_MT_049  \
# 39357                   0.0          16                1093.6
# 39358                   0.0          89                  67.7
# 39359                   1.0          75                  10.4
# 39360                   0.0          39                  60.8
# 39361                   0.0          64                  27.4
# ...                     ...         ...                   ...
# 391629                  0.0          69                 480.0
# 391630                  0.0          63                   6.3
# 391631                  0.0          63                   6.5
# 391632                  1.0          51                  12.1
# 391633                  0.0           6                   7.6
#
#        STRUCTURAL_EVAL_067
# 39357                    7
# 39358                    3
# 39359                    4
# 39360                    7
# 39361                    5
# ...                    ...
# 391629                   6
# 391630                   5
# 391631                   6
# 391632                   5
# 391633                   7
#
# [98159 rows x 28 columns]

# %%
# Splitting the predictor and features dataset
y=df2['BRIDGE_CONDITION'].ravel()
X=df3_filtered

# %%
# one-hot encoding
X = pd.get_dummies(X)

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X)

# Scale the data
X_scaled = pd.DataFrame(X_scaler.transform(X),columns=X.columns)

# Plotting data distributions after scaling
X_scaled.plot(kind='box', showfliers=True, rot=90)
plt.show()

# %%
# Define threshold for outliers
threshold = 10

# Create boolean mask for outliers
outlier_mask = abs(X_scaled) > threshold

# Count the number of outliers along each column (axis=0)
outlier_counts = outlier_mask.sum(axis=0)

print("Number of outliers in each column:")
print(outlier_counts)
# Out:
# Number of outliers in each column:
# ROUTE_PREFIX_005B            0
# SERVICE_LEVEL_005C           0
# MIN_VERT_CLR_010             0
# BASE_HWY_NETWORK_012         0
# TOLL_020                   127
# FUNCTIONAL_CLASS_026         0
# TRAFFIC_LANES_ON_028A        5
# TRAFFIC_LANES_UND_028B      59
# APPR_WIDTH_MT_032           11
# DEGREES_SKEW_034             0
# STRUCTURE_TYPE_043B          0
# APPR_SPANS_046              83
# HORR_CLR_MT_047              0
# MAX_SPAN_LEN_MT_048         58
# STRUCTURE_LEN_MT_049       127
# ROADWAY_WIDTH_MT_051        11
# VERT_CLR_OVER_MT_053         0
# VERT_CLR_UND_054B           60
# OPERATING_RATING_064         0
# APPR_ROAD_EVAL_072           0
# INSPECT_FREQ_MONTHS_091      0
# HIGHWAY_SYSTEM_104           0
# PERCENT_ADT_TRUCK_109       13
# NATIONAL_NETWORK_110         0
# PIER_PROTECTION_111        146
# bridge_age                   0
# STRUCTURE_LEN_MT_049       127
# STRUCTURAL_EVAL_067_*      368
# STRUCTURAL_EVAL_067_0      410
# STRUCTURAL_EVAL_067_2        0
# STRUCTURAL_EVAL_067_3        0
# STRUCTURAL_EVAL_067_4        0
# STRUCTURAL_EVAL_067_5        0
# STRUCTURAL_EVAL_067_6        0
# STRUCTURAL_EVAL_067_7        0
# STRUCTURAL_EVAL_067_8        0
# STRUCTURAL_EVAL_067_9        0
# dtype: int64

# %%
# Filter out rows containing outliers
mask = X_scaled[abs((X_scaled))> threshold].any(axis=1)
X_scaled_clean= X_scaled[~mask]
y_clean = y[~mask]

# number of row eliminated in the original dataset
print('number of row eliminated in the original dataset')
len(X_scaled) - len(X_scaled_clean)
# Out:
# number of row eliminated in the original dataset
# 1299

# %% [markdown]
# ## LogisticRegression model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# Assuming X is your features DataFrame and y is your target variable
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled_clean, y_clean, test_size=0.2, random_state=42)

# Create a pipeline with StandardScaler and Logistic Regression
pipeline = Pipeline([
    ('model', LogisticRegression(max_iter=1000))
])

# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)

# Make predictions on the training and testing data
y_train_pred = pipeline.predict(X_train)
y_test_pred = pipeline.predict(X_test)

# Calculate classification report for training data
print("Classification Report for Training Data:")
print(classification_report(y_train, y_train_pred))

# Calculate classification report for testing data
print("\nClassification Report for Testing Data:")
print(classification_report(y_test, y_test_pred))
# Out:
# Classification Report for Training Data:
#               precision    recall  f1-score   support
#
#            F       0.84      0.86      0.85     39155
#            G       0.87      0.85      0.86     33070
#            P       0.68      0.61      0.65      5263
#
#     accuracy                           0.84     77488
#    macro avg       0.80      0.77      0.78     77488
# weighted avg       0.84      0.84      0.84     77488
#
#
# Classification Report for Testing Data:
#               precision    recall  f1-score   support
#
#            F       0.84      0.86      0.85      9775
#            G       0.86      0.85      0.86      8321
#            P       0.68      0.62      0.65      1276
#
#     accuracy                           0.84     19372
#    macro avg       0.79      0.78      0.78     19372
# weighted avg       0.84      0.84      0.84     19372

# %%
# Visualization of the most important features
# final_model = pipeline.steps[-1][1]
# coefficients = final_model.coef_[0]

# feature_importance = pd.DataFrame({'Feature': X.columns, 'Importance': np.abs(coefficients)})
# feature_importance = feature_importance.sort_values('Importance', ascending=True)
# feature_importance.plot(x='Feature', y='Importance', kind='barh', figsize=(10, 12))
# plt.show()

# %% [markdown]
# ## CatBoostClassifier model

# %%
from catboost import CatBoostClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# Assuming X is your features DataFrame and y is your target variable


# Calculate class weights based on class frequencies
unique_classes, class_counts = np.unique(y_train, return_counts=True)
class_weights = dict(zip(unique_classes, 1 / class_counts))

# Create a CatBoostClassifier with parameters
catboost_params = {
    'l2_leaf_reg': .2,
    'border_count': 32,
    'iterations': 100,
    'class_weights': class_weights,
    'random_state': 42,
    'learning_rate':.1,
    'depth':2,
    'loss_function':'MultiClass'
}

# Create a pipeline with StandardScaler and CatBoostClassifier
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', CatBoostClassifier(**catboost_params))
])

# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)

# Make predictions on the training and testing data
y_train_pred = pipeline.predict(X_train)
y_test_pred = pipeline.predict(X_test)

# Calculate classification report for training data
print("Classification Report for Training Data:")
print(classification_report(y_train, y_train_pred))

# Calculate classification report for testing data
print("\nClassification Report for Testing Data:")
print(classification_report(y_test, y_test_pred))
# Out:
# 0:	learn: 1.0319830	total: 12.1ms	remaining: 1.2s
# 1:	learn: 0.9814015	total: 25.6ms	remaining: 1.25s
# 2:	learn: 0.9418245	total: 39.7ms	remaining: 1.28s
# 3:	learn: 0.9072769	total: 53.3ms	remaining: 1.28s
# 4:	learn: 0.8771204	total: 65.9ms	remaining: 1.25s
# 5:	learn: 0.8487259	total: 79.3ms	remaining: 1.24s
# 6:	learn: 0.8254033	total: 91.5ms	remaining: 1.22s
# 7:	learn: 0.8010834	total: 105ms	remaining: 1.21s
# 8:	learn: 0.7809680	total: 120ms	remaining: 1.21s
# 9:	learn: 0.7636948	total: 132ms	remaining: 1.18s
# 10:	learn: 0.7456848	total: 145ms	remaining: 1.17s
# 11:	learn: 0.7310195	total: 158ms	remaining: 1.16s
# 12:	learn: 0.7183007	total: 170ms	remaining: 1.14s
# 13:	learn: 0.7054619	total: 183ms	remaining: 1.13s
# 14:	learn: 0.6946231	total: 196ms	remaining: 1.11s
# 15:	learn: 0.6841155	total: 209ms	remaining: 1.1s
# 16:	learn: 0.6728619	total: 226ms	remaining: 1.1s
# 17:	learn: 0.6640574	total: 243ms	remaining: 1.11s
# 18:	learn: 0.6552782	total: 258ms	remaining: 1.1s
# 19:	learn: 0.6486671	total: 272ms	remaining: 1.09s
# 20:	learn: 0.6415752	total: 285ms	remaining: 1.07s
# 21:	learn: 0.6349514	total: 299ms	remaining: 1.06s
# 22:	learn: 0.6290715	total: 327ms	remaining: 1.09s
# 23:	learn: 0.6241006	total: 341ms	remaining: 1.08s
# 24:	learn: 0.6199481	total: 355ms	remaining: 1.06s
# 25:	learn: 0.6157326	total: 366ms	remaining: 1.04s
# 26:	learn: 0.6100746	total: 379ms	remaining: 1.02s
# 27:	learn: 0.6057885	total: 390ms	remaining: 1s
# 28:	learn: 0.6013092	total: 402ms	remaining: 985ms
# 29:	learn: 0.5975636	total: 415ms	remaining: 969ms
# 30:	learn: 0.5948177	total: 427ms	remaining: 951ms
# 31:	learn: 0.5913906	total: 439ms	remaining: 932ms
# 32:	learn: 0.5879933	total: 451ms	remaining: 915ms
# 33:	learn: 0.5847138	total: 464ms	remaining: 900ms
# 34:	learn: 0.5821133	total: 476ms	remaining: 883ms
# 35:	learn: 0.5795797	total: 487ms	remaining: 866ms
# 36:	learn: 0.5764465	total: 500ms	remaining: 851ms
# 37:	learn: 0.5744122	total: 512ms	remaining: 836ms
# 38:	learn: 0.5722470	total: 526ms	remaining: 823ms
# 39:	learn: 0.5703770	total: 537ms	remaining: 806ms
# 40:	learn: 0.5684628	total: 548ms	remaining: 789ms
# 41:	learn: 0.5662881	total: 561ms	remaining: 775ms
# 42:	learn: 0.5616170	total: 574ms	remaining: 761ms
# 43:	learn: 0.5601743	total: 586ms	remaining: 746ms
# 44:	learn: 0.5574168	total: 598ms	remaining: 731ms
# 45:	learn: 0.5553904	total: 611ms	remaining: 717ms
# 46:	learn: 0.5537399	total: 624ms	remaining: 704ms
# 47:	learn: 0.5519554	total: 637ms	remaining: 690ms
# 48:	learn: 0.5501195	total: 648ms	remaining: 675ms
# 49:	learn: 0.5487781	total: 662ms	remaining: 662ms
# 50:	learn: 0.5471015	total: 675ms	remaining: 649ms
# 51:	learn: 0.5453876	total: 687ms	remaining: 634ms
# 52:	learn: 0.5440734	total: 699ms	remaining: 620ms
# 53:	learn: 0.5424349	total: 712ms	remaining: 606ms
# 54:	learn: 0.5407813	total: 724ms	remaining: 592ms
# 55:	learn: 0.5396339	total: 735ms	remaining: 578ms
# 56:	learn: 0.5370915	total: 752ms	remaining: 568ms
# 57:	learn: 0.5352457	total: 767ms	remaining: 555ms
# 58:	learn: 0.5339144	total: 782ms	remaining: 543ms
# 59:	learn: 0.5329213	total: 794ms	remaining: 529ms
# 60:	learn: 0.5317732	total: 806ms	remaining: 516ms
# 61:	learn: 0.5307829	total: 818ms	remaining: 502ms
# 62:	learn: 0.5284560	total: 831ms	remaining: 488ms
# 63:	learn: 0.5275469	total: 845ms	remaining: 475ms
# 64:	learn: 0.5263815	total: 857ms	remaining: 462ms
# 65:	learn: 0.5255390	total: 870ms	remaining: 448ms
# 66:	learn: 0.5244445	total: 881ms	remaining: 434ms
# 67:	learn: 0.5234462	total: 893ms	remaining: 420ms
# 68:	learn: 0.5204437	total: 907ms	remaining: 408ms
# 69:	learn: 0.5190875	total: 922ms	remaining: 395ms
# 70:	learn: 0.5180704	total: 934ms	remaining: 381ms
# 71:	learn: 0.5167689	total: 947ms	remaining: 368ms
# 72:	learn: 0.5158865	total: 958ms	remaining: 354ms
# 73:	learn: 0.5150237	total: 972ms	remaining: 342ms
# 74:	learn: 0.5140034	total: 987ms	remaining: 329ms
# 75:	learn: 0.5130942	total: 999ms	remaining: 316ms
# 76:	learn: 0.5122104	total: 1.01s	remaining: 302ms
# 77:	learn: 0.5112444	total: 1.02s	remaining: 289ms
# 78:	learn: 0.5104823	total: 1.04s	remaining: 276ms
# 79:	learn: 0.5095942	total: 1.05s	remaining: 262ms
# 80:	learn: 0.5088637	total: 1.06s	remaining: 249ms
# 81:	learn: 0.5076877	total: 1.07s	remaining: 236ms
# 82:	learn: 0.5069035	total: 1.08s	remaining: 222ms
# 83:	learn: 0.5049685	total: 1.1s	remaining: 209ms
# 84:	learn: 0.5039721	total: 1.11s	remaining: 196ms
# 85:	learn: 0.5018991	total: 1.12s	remaining: 183ms
# 86:	learn: 0.5011586	total: 1.14s	remaining: 170ms
# 87:	learn: 0.4995259	total: 1.15s	remaining: 157ms
# 88:	learn: 0.4985183	total: 1.17s	remaining: 144ms
# 89:	learn: 0.4976778	total: 1.18s	remaining: 131ms
# 90:	learn: 0.4967717	total: 1.19s	remaining: 118ms
# 91:	learn: 0.4958801	total: 1.2s	remaining: 105ms
# 92:	learn: 0.4952785	total: 1.22s	remaining: 91.5ms
# 93:	learn: 0.4945296	total: 1.23s	remaining: 78.3ms
# 94:	learn: 0.4939491	total: 1.24s	remaining: 65.2ms
# 95:	learn: 0.4934635	total: 1.25s	remaining: 52.1ms
# 96:	learn: 0.4924861	total: 1.26s	remaining: 39.1ms
# 97:	learn: 0.4908840	total: 1.28s	remaining: 26.1ms
# 98:	learn: 0.4902571	total: 1.29s	remaining: 13.1ms
# 99:	learn: 0.4896755	total: 1.31s	remaining: 0us
# Classification Report for Training Data:
#               precision    recall  f1-score   support
#
#            F       0.87      0.80      0.84     39155
#            G       0.86      0.85      0.86     33070
#            P       0.50      0.82      0.63      5263
#
#     accuracy                           0.83     77488
#    macro avg       0.75      0.83      0.77     77488
# weighted avg       0.84      0.83      0.83     77488
#
#
# Classification Report for Testing Data:
#               precision    recall  f1-score   support
#
#            F       0.87      0.80      0.84      9775
#            G       0.86      0.86      0.86      8321
#            P       0.50      0.81      0.62      1276
#
#     accuracy                           0.83     19372
#    macro avg       0.74      0.82      0.77     19372
# weighted avg       0.84      0.83      0.83     19372

# %% [markdown]
# ## Multi-layer Perceptron classifier model

# %%
from sklearn.neural_network import MLPClassifier

# Create a pipeline with StandardScaler and MLPClassifier
pipeline = Pipeline([
    ('model', MLPClassifier(hidden_layer_sizes=(100,), activation='relu', solver='adam', 
                            alpha=0.0001, batch_size='auto', learning_rate='constant', learning_rate_init=0.001, 
                            max_iter=1000, shuffle=True, random_state=None, tol=0.0001,validation_fraction=0.2))
])

# Fit the pipeline on the training data
pipeline.fit(X_train, y_train)

# Make predictions on the training and testing data
y_train_pred = pipeline.predict(X_train)
y_test_pred = pipeline.predict(X_test)

# Calculate classification report for training data
print("Classification Report for Training Data:")
print(classification_report(y_train, y_train_pred))

# Calculate classification report for testing data
print("\nClassification Report for Testing Data:")
print(classification_report(y_test, y_test_pred))
# Out:
# Classification Report for Training Data:
#               precision    recall  f1-score   support
#
#            F       0.88      0.87      0.87     39155
#            G       0.87      0.89      0.88     33070
#            P       0.79      0.69      0.74      5263
#
#     accuracy                           0.87     77488
#    macro avg       0.85      0.82      0.83     77488
# weighted avg       0.87      0.87      0.87     77488
#
#
# Classification Report for Testing Data:
#               precision    recall  f1-score   support
#
#            F       0.86      0.85      0.85      9775
#            G       0.85      0.88      0.86      8321
#            P       0.74      0.65      0.69      1276
#
#     accuracy                           0.85     19372
#    macro avg       0.82      0.79      0.80     19372
# weighted avg       0.85      0.85      0.85     19372

# %% [markdown]
# ## Testing the MLP model with bridges in different states

# %%
bridge_df_test = pd.read_csv("Resources/bridge_testing_dataset.csv", low_memory=False)
bridge_df_test.shape
# Out:
# (621579, 73)

# %%
# Selecting AZ and TX states
bridge_AZTX_df = bridge_df_test.loc[(bridge_df_test['STATE_CODE_001'] == 4) | (bridge_df_test['STATE_CODE_001'] == 48),:]
bridge_AZTX_df.head()
# Out:
#        OBJECTID  STATE_CODE_001  ROUTE_PREFIX_005B  SERVICE_LEVEL_005C  \
# 17851     17852               4                  6                   0
# 17852     17853               4                  6                   8
# 17853     17854               4                  6                   8
# 17854     17855               4                  4                   1
# 17855     17856               4                  3                   1
#
#       FEATURES_DESC_006A  MIN_VERT_CLR_010  BASE_HWY_NETWORK_012  TOLL_020  \
# 17851              creek             99.99                   0.0         3
# 17852              creek             99.99                   0.0         3
# 17853              river             99.99                   0.0         3
# 17854               road             99.99                   0.0         3
# 17855              canal             99.99                   0.0         3
#
#        FUNCTIONAL_CLASS_026  TRAFFIC_LANES_ON_028A  TRAFFIC_LANES_UND_028B  \
# 17851                     9                      1                       0
# 17852                     9                      1                       0
# 17853                     6                      2                       4
# 17854                     9                      2                       0
# 17855                     6                      2                       0
#
#        ADT_029 DESIGN_LOAD_031  APPR_WIDTH_MT_032  DEGREES_SKEW_034  \
# 17851       30               C                6.1                 0
# 17852       30               0                3.8                 0
# 17853       30               6                6.1                 0
# 17854      200               5                9.1                14
# 17855      200               5               12.8                35
#
#        STRUCTURE_FLARED_035 RAILINGS_036A TRANSITIONS_036B NAVIGATION_038  \
# 17851                     0             0                0              0
# 17852                     0             0                N              0
# 17853                     0             1                1              0
# 17854                     0             1                1              0
# 17855                     0             1                0              0
#
#        NAV_VERT_CLR_MT_039  NAV_HORR_CLR_MT_040  STRUCTURE_TYPE_043B  \
# 17851                  0.0                  0.0                   10
# 17852                  0.0                  0.0                    3
# 17853                  0.0                  0.0                    2
# 17854                  0.0                  0.0                    5
# 17855                  0.0                  0.0                    2
#
#        MAIN_UNIT_SPANS_045  APPR_SPANS_046  HORR_CLR_MT_047  \
# 17851                    1               0              4.6
# 17852                    1               0              3.8
# 17853                    8               0              6.1
# 17854                    4               0              9.1
# 17855                    1               0             12.8
#
#        MAX_SPAN_LEN_MT_048  STRUCTURE_LEN_MT_049  ROADWAY_WIDTH_MT_051  \
# 17851                 27.4                  28.0                   4.6
# 17852                 16.6                  16.6                  16.6
# 17853                 21.3                 169.8                   6.1
# 17854                 14.0                  56.1                   9.1
# 17855                 33.5                  34.2                  12.8
#
#        DECK_WIDTH_MT_052  VERT_CLR_OVER_MT_053 VERT_CLR_UND_REF_054A  \
# 17851                5.1                 99.99                     N
# 17852               16.6                 99.99                     N
# 17853                7.0                 99.99                     H
# 17854               10.1                 99.99                     N
# 17855               13.6                 99.99                     N
#
#        VERT_CLR_UND_054B DECK_COND_058 SUPERSTRUCTURE_COND_059  \
# 17851               0.00             7                       7
# 17852               0.00             5                       7
# 17853               0.34             7                       7
# 17854               0.00             7                       7
# 17855               0.00             6                       7
#
#       SUBSTRUCTURE_COND_060 CHANNEL_COND_061 CULVERT_COND_062  \
# 17851                     7                8                N
# 17852                     6                N                N
# 17853                     7                8                N
# 17854                     7                8                N
# 17855                     7                8                N
#
#        OPERATING_RATING_064 STRUCTURAL_EVAL_067 DECK_GEOMETRY_EVAL_068  \
# 17851                  47.0                   7                      7
# 17852                   0.0                   *                      9
# 17853                  62.9                   7                      5
# 17854                  86.0                   7                      6
# 17855                  66.4                   7                      9
#
#       UNDCLRENCE_EVAL_069 WATERWAY_EVAL_071  APPR_ROAD_EVAL_072  \
# 17851                   N                 8                 6.0
# 17852                   N                 N                 6.0
# 17853                   3                 9                 8.0
# 17854                   N                 9                 8.0
# 17855                   N                 9                 8.0
#
#        IMP_LEN_MT_076  DATE_OF_INSPECT_090  INSPECT_FREQ_MONTHS_091  \
# 17851             0.0                 1221                       24
# 17852             0.0                 1221                       24
# 17853             0.0                  921                       24
# 17854             0.0                  921                       24
# 17855             0.0                  921                       24
#
#       FRACTURE_092A UNDWATER_LOOK_SEE_092B SPEC_INSPECT_092C  \
# 17851           Y24                      N                 N
# 17852           Y24                      N                 N
# 17853             N                    Y60                 N
# 17854             N                      N                 N
# 17855             N                      N                 N
#
#        BRIDGE_IMP_COST_094  ROADWAY_IMP_COST_095  TOTAL_IMP_COST_096  \
# 17851                  0.0                   0.0                 0.0
# 17852                  0.0                   0.0                 0.0
# 17853                  0.0                   0.0                 0.0
# 17854                  0.0                   0.0               754.0
# 17855                  0.0                   0.0                 0.0
#
#        STRAHNET_HIGHWAY_100 PARALLEL_STRUCTURE_101  HIGHWAY_SYSTEM_104  \
# 17851                     0                      N                   0
# 17852                     0                      N                   0
# 17853                     0                      N                   0
# 17854                     0                      N                   0
# 17855                     0                      N                   0
#
#       DECK_STRUCTURE_TYPE_107 SURFACE_TYPE_108A MEMBRANE_TYPE_108B  \
# 17851                       3                 3                  0
# 17852                       1                 0                  0
# 17853                       1                 0                  0
# 17854                       1                 0                  0
# 17855                       1                 0                  0
#
#       DECK_PROTECTION_108C  PERCENT_ADT_TRUCK_109  NATIONAL_NETWORK_110  \
# 17851                    3                    0.0                     0
# 17852                    0                    0.0                     1
# 17853                    0                    0.0                     0
# 17854                    0                   75.0                     0
# 17855                    0                    0.0                     0
#
#        PIER_PROTECTION_111 BRIDGE_LEN_IND_112 SCOUR_CRITICAL_113  \
# 17851                  0.0                  Y                  8
# 17852                  0.0                  Y                  N
# 17853                  0.0                  Y                  5
# 17854                  0.0                  Y                  8
# 17855                  0.0                  Y                  5
#
#        FUTURE_ADT_114  MIN_NAV_CLR_MT_116 FED_AGENCY BRIDGE_CONDITION  \
# 17851              30                 0.0          Y                G
# 17852              30                 0.0          Y                F
# 17853              75                 0.0          Y                G
# 17854             500                 0.0          Y                G
# 17855             500                 0.0          Y                F
#
#        LOWEST_RATING  DECK_AREA  DATE  bridge_age  future_adt_estimation
# 17851              7     142.80   723          82                   20.0
# 17852              5     275.56   723          82                   19.0
# 17853              7    1188.60   723          13                   22.0
# 17854              7     566.61   723           5                   22.0
# 17855              6     465.12   723          46                   22.0

# %%
df_AT_filtered = bridge_AZTX_df[['ROUTE_PREFIX_005B', 'SERVICE_LEVEL_005C',
       'MIN_VERT_CLR_010', 'BASE_HWY_NETWORK_012', 'TOLL_020',
       'FUNCTIONAL_CLASS_026', 
       'TRAFFIC_LANES_ON_028A','TRAFFIC_LANES_UND_028B', 
       # 'ADT_029', 
       'APPR_WIDTH_MT_032',
       'DEGREES_SKEW_034', #'STRUCTURE_FLARED_035', 
       #'NAV_VERT_CLR_MT_039','NAV_HORR_CLR_MT_040', 
       'STRUCTURE_TYPE_043B', #'MAIN_UNIT_SPANS_045',
       'APPR_SPANS_046', 
       'HORR_CLR_MT_047', 
       'MAX_SPAN_LEN_MT_048','STRUCTURE_LEN_MT_049', 'ROADWAY_WIDTH_MT_051', 
       'VERT_CLR_OVER_MT_053','VERT_CLR_UND_054B', 'OPERATING_RATING_064', 
       'APPR_ROAD_EVAL_072',
       #'IMP_LEN_MT_076', 
       #'DATE_OF_INSPECT_090', 
       'INSPECT_FREQ_MONTHS_091',
       #'BRIDGE_IMP_COST_094', #'ROADWAY_IMP_COST_095', 
       #'STRAHNET_HIGHWAY_100',
       'HIGHWAY_SYSTEM_104', 'PERCENT_ADT_TRUCK_109', 'NATIONAL_NETWORK_110',
       'PIER_PROTECTION_111', #'MIN_NAV_CLR_MT_116', 
       #'LOWEST_RATING', 
       #'DATE',
       'bridge_age',
       'STRUCTURE_LEN_MT_049',
       # 'FEATURES_DESC_006A', 'DESIGN_LOAD_031',
       'STRUCTURAL_EVAL_067',
       ]]

# %%
X_at = df_AT_filtered
y_at = bridge_AZTX_df['BRIDGE_CONDITION'].ravel()

# %%
X_at = pd.get_dummies(X_at)

# %%
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_at)

# Scale the data
X_scaled = pd.DataFrame(X_scaler.transform(X_at),columns=X_at.columns)

X_scaled.plot(kind='box', showfliers=True, rot=90)
plt.show()

# %%
# Define threshold for outliers (e.g., values greater than 10)
threshold = 10

# Create boolean mask for outliers
outlier_mask = abs(X_scaled) > threshold

# Count the number of outliers along each column (axis=0)
outlier_counts = outlier_mask.sum(axis=0)

print("Number of outliers in each column:")
print(outlier_counts)
# Out:
# Number of outliers in each column:
# ROUTE_PREFIX_005B            0
# SERVICE_LEVEL_005C           0
# MIN_VERT_CLR_010             0
# BASE_HWY_NETWORK_012         0
# TOLL_020                    67
# FUNCTIONAL_CLASS_026         0
# TRAFFIC_LANES_ON_028A        8
# TRAFFIC_LANES_UND_028B      39
# APPR_WIDTH_MT_032           17
# DEGREES_SKEW_034             0
# STRUCTURE_TYPE_043B          0
# APPR_SPANS_046             105
# HORR_CLR_MT_047            194
# MAX_SPAN_LEN_MT_048         15
# STRUCTURE_LEN_MT_049       104
# ROADWAY_WIDTH_MT_051         5
# VERT_CLR_OVER_MT_053         0
# VERT_CLR_UND_054B          149
# OPERATING_RATING_064         0
# APPR_ROAD_EVAL_072           1
# INSPECT_FREQ_MONTHS_091      0
# HIGHWAY_SYSTEM_104           0
# PERCENT_ADT_TRUCK_109        0
# NATIONAL_NETWORK_110         0
# PIER_PROTECTION_111         76
# bridge_age                   0
# STRUCTURE_LEN_MT_049       104
# STRUCTURAL_EVAL_067_*       16
# STRUCTURAL_EVAL_067_0       80
# STRUCTURAL_EVAL_067_2      131
# STRUCTURAL_EVAL_067_3      127
# STRUCTURAL_EVAL_067_4        0
# STRUCTURAL_EVAL_067_5        0
# STRUCTURAL_EVAL_067_6        0
# STRUCTURAL_EVAL_067_7        0
# STRUCTURAL_EVAL_067_8        0
# STRUCTURAL_EVAL_067_9      118
# dtype: int64

# %%
# Filter out rows containing outliers
mask = X_scaled[abs((X_scaled))> threshold].any(axis=1)
X_scaled_clean= X_scaled[~mask]
y_clean = y_at[~mask]

# number of row eliminated in the original dataset
print('number of row eliminated in the original dataset')
len(X_scaled) - len(X_scaled_clean)
# Out:
# number of row eliminated in the original dataset
# 1107

# %%
# Model
final_model = pipeline.steps[-1][1]
final_model
# Out:
# MLPClassifier(max_iter=1000, validation_fraction=0.2)

# %%
# Make predictions on the AZ and TX data
y_train_pred_AZTX = pipeline.predict(X_scaled_clean)

# Calculate classification report for training data
print("Classification Report for Training Data:")
print(classification_report(y_clean, y_train_pred_AZTX))
# Out:
# Classification Report for Training Data:
#               precision    recall  f1-score   support
#
#            F       0.75      0.82      0.78     29477
#            G       0.84      0.76      0.80     33663
#            P       0.53      0.88      0.66       610
#
#     accuracy                           0.79     63750
#    macro avg       0.71      0.82      0.75     63750
# weighted avg       0.79      0.79      0.79     63750
